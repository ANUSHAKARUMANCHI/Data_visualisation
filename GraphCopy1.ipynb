# %%
# coding: utf-8

# In[1]:

##########################################################################################################################
#https://plot.ly/streaming/ 
import plotly as py
import plotly.graph_objs as go
import ipywidgets as widgets
import numpy as np
import datetime
py.offline.init_notebook_mode(connected=True)   # for offline mode use

# Reading data from File 
import pandas as pd
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.read_csv('PythonVisual/master.csv')

df
df['year'] = df['country-year'][1][-4:]
#df['year']

# %%
df


# Countries with most terror attacks
###################################################################

terror_filter = df
terror_count = terror_filter.groupby(['country'])['population'].count()
terror_count

countries = pd.DataFrame({'country':terror_count.index,'number':terror_count.values })
data = [dict(
    type='choropleth',
    locations=countries['country'],
    locationmode='country names',
    z=countries['number'],
    text=countries['country'],
    colorscale='Jet',
    reversescale=True,
    marker=dict(line=dict(color='rgb(180,180,180)')),
    colorbar = {'title': 'No of incidents'},
)]
layout = dict(
    title='Countries with most suicide attacks',
    geo=dict(showframe=False, showcoastlines=True, projection=dict(type='mercator')),
    width=1000,
    height=1000,
)
fig = go.Figure(data=data, layout=layout)
py.offline.iplot(fig)
# Out:
# <div>
#
#
#             <div id="760b277d-0b08-4ffa-9f7f-fe626bd9b4f4" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("760b277d-0b08-4ffa-9f7f-fe626bd9b4f4")) {
#                     Plotly.newPlot(
#                         '760b277d-0b08-4ffa-9f7f-fe626bd9b4f4',
# ...
